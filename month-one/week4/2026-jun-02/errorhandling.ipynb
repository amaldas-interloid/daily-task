# %% [markdown]
# # EXCEPTION HANDLING................................

# %%
try:
    print(x)
except NameError:
    print("Variable x is not defined")
except:
    print("Something else went wrong")
# Out:
# Variable x is not defined

# %% [markdown]
# # custom exception................................

# %%
class CustomError(Exception):
    pass


age = 16
try:
    if age < 18:
        raise CustomError("Age must be at least 18")
except CustomError as e:
    print(e)
else:
    print(age)
finally:
    print("This program is completed")
# Out:
# Age must be at least 18
# This program is completed

# %% [markdown]
# # bank program........................................

# %%
class insufficientbalanceError(Exception):
    pass


balance = 1000
withdraw = 500
try:
    if withdraw > balance:
        raise insufficientbalanceError("insufficient amount")
except TypeError:
    print("Invalid input type")
except insufficientbalanceError as e:
    print(e)
else:
    print("withdraw successful")
finally:
    print("Transaction completed")

# %% [markdown]
# # logging..............................

# %% [markdown]
# ### logging is the process of recording information about what your program is doing while running
# ###                    instead of doing lot of print() statements ,we can use built-in  python logging module..........

# %%
import logging

logging.basicConfig(level=logging.DEBUG)

logging.debug("Debug message")
logging.info("Program started")
logging.warning("Low disk space")
logging.error("File not found")
logging.critical("System crash")

# %%
import logging

try:
    logging.basicConfig(level=logging.INFO)
    result = 10 / 0
except ZeroDivisionError as e:
    logging.error("An error occurred:")

# %%
import logging

logging.basicConfig(level=logging.INFO)
balance = 1200
withdraw = 2500
try:
    logging.info(f" THe current balance is {balance}")
    logging.info(f" The amount to withdraw is {withdraw}")
    if withdraw > balance:
        raise insufficientbalanceError(f"insufficient amount in the account:{balance}")
    balance -= withdraw
    logging.info(f"withdraw sucessful..........your balance amountis {balance}")
except TypeError:
    logging.error("Invalid input type")
except insufficientbalanceError as e:
    logging.error(e)
