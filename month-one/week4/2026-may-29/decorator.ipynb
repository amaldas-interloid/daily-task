# %%
# noramal

# %% [markdown]
# # @property

# %% [markdown]
# ### Allows you to use a method like attributes(variable)

# %%
class student:
    @property
    def get_name(self):
        return "amal"
s = student()
print(s.get_name)
# Out:
# amal
